# %%
url="https://archive.ics.uci.edu/dataset/45/heart+disease"

# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(janitor)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.5     ✔ rsample      1.2.0
# ✔ dials        1.2.0     ✔ tune         1.1.2
# ✔ infer        1.0.4     ✔ workflows    1.1.3
# ✔ modeldata    1.2.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.1.1     ✔ yardstick    1.2.0
# ✔ recipes      1.0.8
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Learn how to get started at https://www.tidymodels.org/start/
#
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test

# %%
main_data_column_2 <- read_table("cleve.mod", col_names = c('Age', 'Sex', 'Chest Pain Type', 'Resting Blood Pressure',
                                                            'Cholesterol', 'Fasting Blood Sugar <120',
                                                        'Resting ECG Reading', 'Max Heart Rate',
                                                       'Exercise Induced Angina (TRUE or FALSE)',
                                                            'Old Peak', 'Slope', 'Number Of Vessels Coloured', 'thal','Health'), skip = 20)

heart_data<-clean_names(main_data_column_2)
heart_data <- heart_data |>
        mutate(health = as_factor(health))
heart_data
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   Age = col_double(),
#   Sex = col_character(),
#   `Chest Pain Type` = col_character(),
#   `Resting Blood Pressure` = col_double(),
#   Cholesterol = col_double(),
#   `Fasting Blood Sugar <120` = col_character(),
#   `Resting ECG Reading` = col_character(),
#   `Max Heart Rate` = col_double(),
#   `Exercise Induced Angina (TRUE or FALSE)` = col_character(),
#   `Old Peak` = col_double(),
#   Slope = col_character(),
#   `Number Of Vessels Coloured` = col_character(),
#   thal = col_character(),
#   Health = col_character()
# )
#
# Warning message:
# “303 parsing failures.
# row col   expected     actual        file
#   1  -- 14 columns 15 columns 'cleve.mod'
#   2  -- 14 columns 15 columns 'cleve.mod'
#   3  -- 14 columns 15 columns 'cleve.mod'
#   4  -- 14 columns 15 columns 'cleve.mod'
#   5  -- 14 columns 15 columns 'cleve.mod'
# ... ... .......... .......... ...........
# See problems(...) for more details.
# ”
#     age sex  chest_pain_type resting_blood_pressure cholesterol
# 1   63  male angina          145                    233
# 2   67  male asympt          160                    286
# 3   67  male asympt          120                    229
# 4   37  male notang          130                    250
# 5   41  fem  abnang          130                    204
# 6   56  male abnang          120                    236
# 7   62  fem  asympt          140                    268
# 8   57  fem  asympt          120                    354
# 9   63  male asympt          130                    254
# 10  53  male asympt          140                    203
# 11  57  male asympt          140                    192
# 12  56  fem  abnang          140                    294
# 13  56  male notang          130                    256
# 14  44  male abnang          120                    263
# 15  49  male abnang          130                    266
# 16  64  male angina          110                    211
# 17  58  fem  angina          150                    283
# 18  58  male abnang          120                    284
# 19  58  male notang          132                    224
# 20  60  male asympt          130                    206
# 21  50  fem  notang          120                    219
# 22  58  fem  notang          120                    340
# 23  66  fem  angina          150                    226
# 24  43  male asympt          150                    247
# 25  40  male asympt          110                    167
# 26  69  fem  angina          140                    239
# 27  60  male asympt          117                    230
# 28  64  male notang          140                    335
# 29  59  male asympt          135                    234
# 30  44  male notang          130                    233
# ⋮   ⋮   ⋮    ⋮               ⋮                      ⋮
# 274 57  fem  asympt          128                    303
# 275 71  fem  notang          110                    265
# 276 49  male notang          120                    188
# 277 54  male abnang          108                    309
# 278 59  male asympt          140                    177
# 279 57  male notang          128                    229
# 280 65  male angina          138                    282
# 281 45  fem  abnang          130                    234
# 282 56  fem  asympt          200                    288
# 283 54  male asympt          110                    239
# 284 44  male abnang          120                    220
# 285 62  fem  asympt          124                    209
# 286 54  male notang          120                    258
# 287 51  male notang           94                    227
# 288 44  fem  notang          118                    242
# 289 58  fem  abnang          136                    319
# 290 60  fem  angina          150                    240
# 291 44  male notang          120                    226
# 292 61  male asympt          138                    166
# 293 42  male asympt          136                    315
# 294 68  male notang          118                    277
# 295 46  male abnang          101                    197
# 296 77  male asympt          125                    304
# 297 54  fem  notang          110                    214
# 298 58  fem  asympt          100                    248
# 299 48  male notang          124                    255
# 300 57  male asympt          132                    207
# 301 49  male notang          118                    149
# 302 74  fem  abnang          120                    269
# 303 54  fem  notang          160                    201
#     fasting_blood_sugar_120 resting_ecg_reading max_heart_rate
# 1   true                    hyp                 150
# 2   fal                     hyp                 108
# 3   fal                     hyp                 129
# 4   fal                     norm                187
# 5   fal                     hyp                 172
# 6   fal                     norm                178
# 7   fal                     hyp                 160
# 8   fal                     norm                163
# 9   fal                     hyp                 147
# 10  true                    hyp                 155
# 11  fal                     norm                148
# 12  fal                     hyp                 153
# 13  true                    hyp                 142
# 14  fal                     norm                173
# 15  fal                     norm                171
# 16  fal                     hyp                 144
# 17  true                    hyp                 162
# 18  fal                     hyp                 160
# 19  fal                     hyp                 173
# 20  fal                     hyp                 132
# 21  fal                     norm                158
# 22  fal                     norm                172
# 23  fal                     norm                114
# 24  fal                     norm                171
# 25  fal                     hyp                 114
# 26  fal                     norm                151
# 27  true                    norm                160
# 28  fal                     norm                158
# 29  fal                     norm                161
# 30  fal                     norm                179
# ⋮   ⋮                       ⋮                   ⋮
# 274 fal                     hyp                 159
# 275 true                    hyp                 130
# 276 fal                     norm                139
# 277 fal                     norm                156
# 278 fal                     norm                162
# 279 fal                     hyp                 150
# 280 true                    hyp                 174
# 281 fal                     hyp                 175
# 282 true                    hyp                 133
# 283 fal                     norm                126
# 284 fal                     norm                170
# 285 fal                     norm                163
# 286 fal                     hyp                 147
# 287 fal                     norm                154
# 288 fal                     norm                149
# 289 true                    hyp                 152
# 290 fal                     norm                171
# 291 fal                     norm                169
# 292 fal                     hyp                 125
# 293 fal                     norm                125
# 294 fal                     norm                151
# 295 true                    norm                156
# 296 fal                     hyp                 162
# 297 fal                     norm                158
# 298 fal                     hyp                 122
# 299 true                    norm                175
# 300 fal                     norm                168
# 301 fal                     hyp                 126
# 302 fal                     hyp                 121
# 303 fal                     norm                163
#     exercise_induced_angina_true_or_false old_peak slope
# 1   fal                                   2.3      down
# 2   true                                  1.5      flat
# 3   true                                  2.6      flat
# 4   fal                                   3.5      down
# 5   fal                                   1.4      up
# 6   fal                                   0.8      up
# 7   fal                                   3.6      down
# 8   true                                  0.6      up
# 9   fal                                   1.4      flat
# 10  true                                  3.1      down
# 11  fal                                   0.4      flat
# 12  fal                                   1.3      flat
# 13  true                                  0.6      flat
# 14  fal                                   0.0      up
# 15  fal                                   0.6      up
# 16  true                                  1.8      flat
# 17  fal                                   1.0      up
# 18  fal                                   1.8      flat
# 19  fal                                   3.2      up
# 20  true                                  2.4      flat
# 21  fal                                   1.6      flat
# 22  fal                                   0.0      up
# 23  fal                                   2.6      down
# 24  fal                                   1.5      up
# 25  true                                  2.0      flat
# 26  fal                                   1.8      up
# 27  true                                  1.4      up
# 28  fal                                   0.0      up
# 29  fal                                   0.5      flat
# 30  true                                  0.4      up
# ⋮   ⋮                                     ⋮        ⋮
# 274 fal                                   0.0      up
# 275 fal                                   0.0      up
# 276 fal                                   2.0      flat
# 277 fal                                   0.0      up
# 278 true                                  0.0      up
# 279 fal                                   0.4      flat
# 280 fal                                   1.4      flat
# 281 fal                                   0.6      flat
# 282 true                                  4.0      down
# 283 true                                  2.8      flat
# 284 fal                                   0.0      up
# 285 fal                                   0.0      up
# 286 fal                                   0.4      flat
# 287 true                                  0.0      up
# 288 fal                                   0.3      flat
# 289 fal                                   0.0      up
# 290 fal                                   0.9      up
# 291 fal                                   0.0      up
# 292 true                                  3.6      flat
# 293 true                                  1.8      flat
# 294 fal                                   1.0      up
# 295 fal                                   0.0      up
# 296 true                                  0.0      up
# 297 fal                                   1.6      flat
# 298 fal                                   1.0      flat
# 299 fal                                   0.0      up
# 300 true                                  0.0      up
# 301 fal                                   0.8      up
# 302 true                                  0.2      up
# 303 fal                                   0.0      up
#     number_of_vessels_coloured thal health
# 1   0.0                        fix  buff
# 2   3.0                        norm sick
# 3   2.0                        rev  sick
# 4   0.0                        norm buff
# 5   0.0                        norm buff
# 6   0.0                        norm buff
# 7   2.0                        norm sick
# 8   0.0                        norm buff
# 9   1.0                        rev  sick
# 10  0.0                        rev  sick
# 11  0.0                        fix  buff
# 12  0.0                        norm buff
# 13  1.0                        fix  sick
# 14  0.0                        rev  buff
# 15  0.0                        norm buff
# 16  0.0                        norm buff
# 17  0.0                        norm buff
# 18  0.0                        norm sick
# 19  2.0                        rev  sick
# 20  2.0                        rev  sick
# 21  0.0                        norm buff
# 22  0.0                        norm buff
# 23  0.0                        norm buff
# 24  0.0                        norm buff
# 25  0.0                        rev  sick
# 26  2.0                        norm buff
# 27  2.0                        rev  sick
# 28  0.0                        norm sick
# 29  0.0                        rev  buff
# 30  0.0                        norm buff
# ⋮   ⋮                          ⋮    ⋮
# 274 1.0                        norm buff
# 275 1.0                        norm buff
# 276 3.0                        rev  sick
# 277 0.0                        rev  buff
# 278 1.0                        rev  sick
# 279 1.0                        rev  sick
# 280 1.0                        norm sick
# 281 0.0                        norm buff
# 282 2.0                        rev  sick
# 283 1.0                        rev  sick
# 284 0.0                        norm buff
# 285 0.0                        norm buff
# 286 0.0                        rev  buff
# 287 1.0                        rev  buff
# 288 1.0                        norm buff
# 289 2.0                        norm sick
# 290 0.0                        norm buff
# 291 0.0                        norm buff
# 292 1.0                        norm sick
# 293 0.0                        fix  sick
# 294 1.0                        rev  buff
# 295 0.0                        rev  buff
# 296 3.0                        norm sick
# 297 0.0                        norm buff
# 298 0.0                        norm buff
# 299 2.0                        norm buff
# 300 0.0                        rev  buff
# 301 3.0                        norm sick
# 302 1.0                        norm buff
# 303 1.0                        norm buff

# %%
#Heart K nearest neighbors
heart_split<-initial_split(heart_data,prop=0.75,strata=health)  
heart_train<-training(heart_split)   
heart_test<-testing(heart_split)

heart_recipe<-recipe(health~cholesterol+resting_blood_pressure,data=heart_train)|>
   step_scale(all_predictors())|>
   step_center(all_predictors())

knn_spec<-nearest_neighbor(weight_func="rectangular",neighbors=3)|>
      set_engine("kknn")|>
      set_mode("classification")

heart_fit<-workflow()|>
      add_recipe(heart_recipe)|>
      add_model(knn_spec)|>
      fit(data=heart_train)

heart_fit

heart_test_predictions<-predict(heart_fit,heart_test)|>
      bind_cols(heart_test)


#Heart data scaled 
heart_data_recipe<-recipe(health~cholesterol+resting_blood_pressure,data=heart_data)|>
    step_scale(all_predictors())|>
    step_center(all_predictors())|>
    prep()
heart_data_scaled<-bake(heart_data_recipe,heart_data)
#heart_data_scaled

#Heart data plot
heart_plot<-heart_data|>
    ggplot(aes(x=resting_blood_pressure,y=cholesterol,color=health))+
    geom_point()+
    labs(x="Resting Blood Pressure ",y="Cholesterol", color="Health")+
    theme(text=element_text(size=20))
  #  facet_grid(.~sex)
heart_plot



#Checking which K should use
heart_vfold<-vfold_cv(heart_train, v=10,strata=health)

knn_tune<-nearest_neighbor(weight_func="rectangular",neighbors=tune())|>
      set_engine("kknn")|>
      set_mode("classification")
knn_tune

knn_results<-workflow()|>
      add_recipe(heart_recipe)|>
      add_model(knn_tune)|>
      tune_grid(resamples=heart_vfold,grid=10)|>
      collect_metrics()
knn_results

accuracies<-knn_results|> 
      filter(.metric=="accuracy")

accuracy_versus_k<-ggplot(accuracies,aes(x=neighbors,y=mean))+
      geom_point()+
      geom_line()+
      labs(x="Neighbors",y="Accuracy Estimate") +
      scale_x_continuous(breaks=seq(0,14,by=1))+  
      scale_y_continuous(limits=c(0.4,1.0))
accuracy_versus_k
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# • step_scale()
# • step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = min_rows(3,     data, 5), kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.4823009
# Best kernel: rectangular
# Best k: 3
# K-Nearest Neighbor Model Specification (classification)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn
#    neighbors .metric  .estimator mean      n  std_err    .config
# 1   2        accuracy binary     0.4700758 10 0.03004122 Preprocessor1_Model1
# 2   2        roc_auc  binary     0.5143386 10 0.03393222 Preprocessor1_Model1
# 3   3        accuracy binary     0.5037879 10 0.02213020 Preprocessor1_Model2
# 4   3        roc_auc  binary     0.4921125 10 0.02325732 Preprocessor1_Model2
# 5   4        accuracy binary     0.5083333 10 0.01920521 Preprocessor1_Model3
# 6   4        roc_auc  binary     0.5354633 10 0.02871763 Preprocessor1_Model3
# 7   6        accuracy binary     0.5469697 10 0.02077931 Preprocessor1_Model4
# 8   6        roc_auc  binary     0.5424038 10 0.03519636 Preprocessor1_Model4
# 9   8        accuracy binary     0.5636364 10 0.03501734 Preprocessor1_Model5
# 10  8        roc_auc  binary     0.5540705 10 0.03955273 Preprocessor1_Model5
# 11 10        accuracy binary     0.5329545 10 0.03182244 Preprocessor1_Model6
# 12 10        roc_auc  binary     0.5465559 10 0.03004241 Preprocessor1_Model6
# 13 11        accuracy binary     0.5560606 10 0.03236759 Preprocessor1_Model7
# 14 11        roc_auc  binary     0.5625612 10 0.02857065 Preprocessor1_Model7
# 15 13        accuracy binary     0.5518939 10 0.02884790 Preprocessor1_Model8
# 16 13        roc_auc  binary     0.5390734 10 0.02876663 Preprocessor1_Model8
# 17 15        accuracy binary     0.5090909 10 0.02409070 Preprocessor1_Model9
# 18 15        roc_auc  binary     0.5159207 10 0.02819509 Preprocessor1_Model9
# plot without title
# plot without title
